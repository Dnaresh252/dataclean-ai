# %%
"""
Generate Training Dataset
=========================

Goal: Create 50 synthetic messy files for ML training

Process:
1. Load clean datasets
2. Run generator on each
3. Save messy files + labels
4. Create train/validation/test splits
"""

import pandas as pd
import sys
sys.path.append('../ml_pipeline')

from data.synthetic_data_generator import SyntheticDataGenerator
import json
from pathlib import Path

print("✅ Generator imported")
# Out:
# ✅ Generator imported

# %%
"""
We'll use seaborn's built-in datasets as "clean" starting points
Then make them messy!
"""

import seaborn as sns

# Load multiple clean datasets
datasets = {
    'titanic': sns.load_dataset('titanic'),
    'tips': sns.load_dataset('tips'),
    'iris': sns.load_dataset('iris'),
    'diamonds': sns.load_dataset('diamonds').sample(200),  # Sample to keep small
    'planets': sns.load_dataset('planets'),
}

print("Clean datasets loaded:")
for name, df in datasets.items():
    print(f"  - {name}: {df.shape}")
# Out:
# Clean datasets loaded:
#   - titanic: (891, 15)
#   - tips: (244, 7)
#   - iris: (150, 5)
#   - diamonds: (200, 10)
#   - planets: (1035, 6)

# %%
"""
For each clean dataset, generate multiple messy versions
with different problem combinations
"""

# Create output directories
Path('../data/synthetic/messy').mkdir(parents=True, exist_ok=True)
Path('../data/synthetic/labels').mkdir(parents=True, exist_ok=True)

# Generate messy datasets
all_labels = []
file_counter = 0

for dataset_name, clean_df in datasets.items():
    print(f"\n{'='*60}")
    print(f"Processing: {dataset_name}")
    print(f"{'='*60}")
    
    # Generate 3 different messy versions of each dataset
    # (different random seeds = different problems)
    for version in range(3):
        file_counter += 1
        
        # Initialize generator with different seed
        generator = SyntheticDataGenerator(clean_df, seed=42 + version)
        
        # Generate messy data
        messy_df, labels = generator.generate()
        
        # Save messy CSV
        filename = f"messy_{file_counter:03d}_{dataset_name}_v{version}.csv"
        filepath = f'../data/synthetic/messy/{filename}'
        messy_df.to_csv(filepath, index=False)
        
        # Update labels
        labels['filename'] = filename
        labels['source_dataset'] = dataset_name
        labels['version'] = version
        
        # Save labels JSON
        label_filepath = f'../data/synthetic/labels/{filename.replace(".csv", ".json")}'
        with open(label_filepath, 'w') as f:
            json.dump(labels, f, indent=2)
        
        all_labels.append(labels)
        
        print(f"  ✅ Generated: {filename}")

print(f"\n{'='*60}")
print(f"✅ Total files generated: {file_counter}")
print(f"{'='*60}")
# Out:
# ============================================================
# Processing: titanic
# ============================================================
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 89 duplicate rows (10.0%)
# ✅ Created 1858 missing values (12.6% of cells)
# ✅ Created 49 fuzzy duplicates in ['sex', 'embarked']
# ✅ Added 3 outliers to column 'survived'
# ✅ Added 3 outliers to column 'pclass'
# ✅ Converted column 'survived' to string (type issue)
#
# ✅ Generation complete!
#    Original: (891, 15)
#    Messy: (980, 15)
#    Problems: 6 types injected
#   ✅ Generated: messy_001_titanic_v0.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 89 duplicate rows (10.0%)
# ✅ Created 1876 missing values (12.8% of cells)
# ✅ Created 49 fuzzy duplicates in ['sex', 'embarked']
# ✅ Added 3 outliers to column 'survived'
# ✅ Added 3 outliers to column 'pclass'
# ✅ Converted column 'survived' to string (type issue)
#
# ✅ Generation complete!
#    Original: (891, 15)
#    Messy: (980, 15)
#    Problems: 6 types injected
#   ✅ Generated: messy_002_titanic_v1.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 89 duplicate rows (10.0%)
# ✅ Created 1891 missing values (12.9% of cells)
# ✅ Created 49 fuzzy duplicates in ['sex', 'embarked']
# ✅ Added 3 outliers to column 'survived'
# ✅ Added 3 outliers to column 'pclass'
# ✅ Converted column 'survived' to string (type issue)
#
# ✅ Generation complete!
#    Original: (891, 15)
#    Messy: (980, 15)
#    Problems: 6 types injected
#   ✅ Generated: messy_003_titanic_v2.csv
#
# ============================================================
# Processing: tips
# ============================================================
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 24 duplicate rows (10.0%)
# ✅ Created 261 missing values (13.9% of cells)
# ✅ Added 3 outliers to column 'total_bill'
# ✅ Added 3 outliers to column 'tip'
# ✅ Converted column 'total_bill' to string (type issue)
#
# ✅ Generation complete!
#    Original: (244, 7)
#    Messy: (268, 7)
#    Problems: 5 types injected
#   ✅ Generated: messy_004_tips_v0.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 24 duplicate rows (10.0%)
# ✅ Created 261 missing values (13.9% of cells)
# ✅ Added 3 outliers to column 'total_bill'
# ✅ Added 3 outliers to column 'tip'
# ✅ Converted column 'total_bill' to string (type issue)
#
# ✅ Generation complete!
#    Original: (244, 7)
#    Messy: (268, 7)
#    Problems: 5 types injected
#   ✅ Generated: messy_005_tips_v1.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 24 duplicate rows (10.0%)
# ✅ Created 261 missing values (13.9% of cells)
# ✅ Added 3 outliers to column 'total_bill'
# ✅ Added 3 outliers to column 'tip'
# ✅ Converted column 'total_bill' to string (type issue)
#
# ✅ Generation complete!
#    Original: (244, 7)
#    Messy: (268, 7)
#    Problems: 5 types injected
#   ✅ Generated: messy_006_tips_v2.csv
#
# ============================================================
# Processing: iris
# ============================================================
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 15 duplicate rows (10.0%)
# ✅ Created 113 missing values (13.7% of cells)
# ✅ Created 8 fuzzy duplicates in ['species']
# ✅ Added 3 outliers to column 'sepal_length'
# ✅ Added 3 outliers to column 'sepal_width'
# ✅ Converted column 'sepal_length' to string (type issue)
#
# ✅ Generation complete!
#    Original: (150, 5)
#    Messy: (165, 5)
#    Problems: 6 types injected
#   ✅ Generated: messy_007_iris_v0.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 15 duplicate rows (10.0%)
# ✅ Created 118 missing values (14.3% of cells)
# ✅ Created 8 fuzzy duplicates in ['species']
# ✅ Added 3 outliers to column 'sepal_length'
# ✅ Added 3 outliers to column 'sepal_width'
# ✅ Converted column 'sepal_length' to string (type issue)
#
# ✅ Generation complete!
#    Original: (150, 5)
#    Messy: (165, 5)
#    Problems: 6 types injected
#   ✅ Generated: messy_008_iris_v1.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 15 duplicate rows (10.0%)
# ✅ Created 116 missing values (14.1% of cells)
# ✅ Created 8 fuzzy duplicates in ['species']
# ✅ Added 3 outliers to column 'sepal_length'
# ✅ Added 3 outliers to column 'sepal_width'
# ✅ Converted column 'sepal_length' to string (type issue)
#
# ✅ Generation complete!
#    Original: (150, 5)
#    Messy: (165, 5)
#    Problems: 6 types injected
#   ✅ Generated: messy_009_iris_v2.csv
#
# ============================================================
# Processing: diamonds
# ============================================================
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 20 duplicate rows (10.0%)
# ✅ Created 305 missing values (13.9% of cells)
# ✅ Added 3 outliers to column 'carat'
# ✅ Added 3 outliers to column 'depth'
# ✅ Converted column 'carat' to string (type issue)
#
# ✅ Generation complete!
#    Original: (200, 10)
#    Messy: (220, 10)
#    Problems: 5 types injected
#   ✅ Generated: messy_010_diamonds_v0.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 20 duplicate rows (10.0%)
# ✅ Created 307 missing values (14.0% of cells)
# ✅ Added 3 outliers to column 'carat'
# ✅ Added 3 outliers to column 'depth'
# ✅ Converted column 'carat' to string (type issue)
#
# ✅ Generation complete!
#    Original: (200, 10)
#    Messy: (220, 10)
#    Problems: 5 types injected
#   ✅ Generated: messy_011_diamonds_v1.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 20 duplicate rows (10.0%)
# ✅ Created 302 missing values (13.7% of cells)
# ✅ Added 3 outliers to column 'carat'
# ✅ Added 3 outliers to column 'depth'
# ✅ Converted column 'carat' to string (type issue)
#
# ✅ Generation complete!
#    Original: (200, 10)
#    Messy: (220, 10)
#    Problems: 5 types injected
#   ✅ Generated: messy_012_diamonds_v2.csv
#
# ============================================================
# Processing: planets
# ============================================================
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 103 duplicate rows (10.0%)
# ✅ Created 829 missing values (12.1% of cells)
# ✅ Created 56 fuzzy duplicates in ['method']
# ✅ Added 3 outliers to column 'number'
# ✅ Added 3 outliers to column 'orbital_period'
# ✅ Converted column 'number' to string (type issue)
#
# ✅ Generation complete!
#    Original: (1035, 6)
#    Messy: (1138, 6)
#    Problems: 6 types injected
#   ✅ Generated: messy_013_planets_v0.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 103 duplicate rows (10.0%)
# ✅ Created 811 missing values (11.9% of cells)
# ✅ Created 56 fuzzy duplicates in ['method']
# ✅ Added 3 outliers to column 'number'
# ✅ Added 3 outliers to column 'orbital_period'
# ✅ Converted column 'number' to string (type issue)
#
# ✅ Generation complete!
#    Original: (1035, 6)
#    Messy: (1138, 6)
#    Problems: 6 types injected
#   ✅ Generated: messy_014_planets_v1.csv
#
# 🔧 Generating synthetic messy data...
#
# ✅ Injected 103 duplicate rows (10.0%)
# ✅ Created 833 missing values (12.2% of cells)
# ✅ Created 56 fuzzy duplicates in ['method']
# ✅ Added 3 outliers to column 'number'
# ✅ Added 3 outliers to column 'orbital_period'
# ✅ Converted column 'number' to string (type issue)
#
# ✅ Generation complete!
#    Original: (1035, 6)
#    Messy: (1138, 6)
#    Problems: 6 types injected
#   ✅ Generated: messy_015_planets_v2.csv
#
# ============================================================
# ✅ Total files generated: 15
# ============================================================

# %%
"""
Combine all labels into one master file for easy loading
"""

master_labels_path = '../data/synthetic/labels/master_labels.json'

with open(master_labels_path, 'w') as f:
    json.dump(all_labels, f, indent=2)

print(f"✅ Master labels saved: {master_labels_path}")
print(f"   Total labeled files: {len(all_labels)}")
# Out:
# ✅ Master labels saved: ../data/synthetic/labels/master_labels.json
#    Total labeled files: 15

# %%
"""
Quick check to make sure everything worked
"""

from pathlib import Path

# Load one messy file
sample_file = Path('../data/synthetic/messy/messy_001_titanic_v0.csv')
sample_df = pd.read_csv(sample_file)

print("📄 Sample messy file:")
print(f"   File: {sample_file}")
print(f"   Shape: {sample_df.shape}")
print(f"\nFirst few rows:")
print(sample_df.head())

# Construct label file path properly
label_file = Path('../data/synthetic/labels') / sample_file.name.replace('.csv', '.json')
print(f"\nLooking for labels at: {label_file}")

with open(label_file, 'r') as f:
    sample_labels = json.load(f)

print(f"\n📊 Labels for this file:")
print(json.dumps(sample_labels['problems_injected'], indent=2))

print(f"\n✅ Success! Generated messy data with labels")
# Out:
# 📄 Sample messy file:
#    File: ..\data\synthetic\messy\messy_001_titanic_v0.csv
#    Shape: (980, 15)
#
# First few rows:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0       0.0     3.0    male  22.0    1.0    0.0   7.2500        S  Third
# 1       1.0     1.0  female  38.0    1.0    0.0  71.2833        C  First
# 2       1.0     3.0  FEMALE  26.0    NaN    0.0      NaN        s  Third
# 3       1.0     1.0  female  35.0    1.0    0.0  53.1000        S  First
# 4       0.0     3.0    male  35.0    0.0    0.0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C          NaN   yes  False
# 4    man        True  NaN          NaN    no   True
#
# Looking for labels at: ..\data\synthetic\labels\messy_001_titanic_v0.json
#
# 📊 Labels for this file:
# [
#   {
#     "type": "duplicates",
#     "count": 89,
#     "percentage": 10.0
#   },
#   {
#     "type": "missing_values",
#     "count": 1858,
#     "percentage": 12.639455782312925
#   },
#   {
#     "type": "fuzzy_duplicates",
#     "columns": [
#       "sex",
#       "embarked"
#     ],
#     "count": 49
#   },
#   {
#     "type": "outliers",
#     "column": "survived",
#     "count": 3
#   },
#   {
#     "type": "outliers",
#     "column": "pclass",
#     "count": 3
#   },
#   {
#     "type": "data_type_issue",
#     "column": "survived",
#     "converted_to": "string"
#   }
# ]
#
# ✅ Success! Generated messy data with labels
